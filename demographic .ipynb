# %%
# !pip install jovian --upgrade --quiet
# Out:
#      |████████████████████████████████| 68 kB 6.2 MB/s
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("adult .csv")

# %%
race_counts=df["race"].value_counts()

# %%
race_counts
# Out:
# White                 32924
# Black                  3671
# Asian-Pac-Islander     1171
# Amer-Indian-Eskimo      374
# Other                   323
# Name: race, dtype: int64

# %%
df
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 0       25           Private  226802          11th                7
# 1       38           Private   89814       HS-grad                9
# 2       28         Local-gov  336951    Assoc-acdm               12
# 3       44           Private  160323  Some-college               10
# 4       18                 ?  103497  Some-college               10
# ...    ...               ...     ...           ...              ...
# 38459   42           Private  341757  Some-college               10
# 38460   36           Private  218542       HS-grad                9
# 38461   44         Local-gov  190020     Bachelors               13
# 38462   27           Private  221436     Bachelors               13
# 38463   39  Self-emp-not-inc   52187       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# ...

# %%
average_age_men=df[df["gender"]=="Male"]["age"].mean()

# %%
average_age_men
# Out:
# 39.476209002840136

# %%
bachelors_percentage=(len(df[df["education"]=="Bachelors"])/len(df))*100

# %%
bachelors_percentage
# Out:
# 16.524542429284526

# %%
educated_groups=[df[df["education"]=="Bachelors"],df[df["education"]=="Masters"],df[df["education"]=="Docatrate"]]

# %%
educated_groups
# Out:
# [       age         workclass  fnlwgt  education  educational-num  \
#  11      36       Federal-gov  212465  Bachelors               13
#  20      34           Private  107914  Bachelors               13
#  23      25           Private  220931  Bachelors               13
#  24      25           Private  205947  Bachelors               13
#  32      24  Self-emp-not-inc  188274  Bachelors               13
#  ...    ...               ...     ...        ...              ...
#  38450   48           Private  344415  Bachelors               13
#  38452   43           Private   27766  Bachelors               13
#  38455   41           Private   22201  Bachelors               13
#  38461   44         Local-gov  190020  Bachelors               13
#  38462   27           Private  221436  Bachelors               13
#
#                marital-status       occupation   relationship  \
#  11        Married-civ-spouse     Adm-clerical        Husband
# ...

# %%
educated_groups=pd.concat(educated_groups)

# %%
educated_groups
# Out:
#        age         workclass  fnlwgt  education  educational-num  \
# 11      36       Federal-gov  212465  Bachelors               13
# 20      34           Private  107914  Bachelors               13
# 23      25           Private  220931  Bachelors               13
# 24      25           Private  205947  Bachelors               13
# 32      24  Self-emp-not-inc  188274  Bachelors               13
# ...    ...               ...     ...        ...              ...
# 38409   55  Self-emp-not-inc  157486    Masters               14
# 38411   67                 ?   81761    Masters               14
# 38422   39           Private  202937    Masters               14
# 38434   57           Private  170287    Masters               14
# 38456   35      Self-emp-inc  187046    Masters               14
#
#            marital-status      occupation   relationship   race  gender  \
# 11     Married-civ-spouse    Adm-clerical        Husband  White    Male
# ...

# %%
percentage_higher_education=(len(educated_groups[educated_groups["income"]==">50K"])/len(educated_groups))*100

# %%
round(percentage_higher_education,1)
# Out:
# 44.4

# %%
uneducated_groups = df[df["education"] != "Bachelors"]
uneducated_groups = uneducated_groups[uneducated_groups["education"] != "Masters"]
uneducated_groups = uneducated_groups[uneducated_groups["education"] != "Doctorate"]

lower_education_rich = round ( (len( uneducated_groups[uneducated_groups["income"] == ">50K"]) / len(uneducated_groups)) * 100, 1)

# %%
uneducated_groups
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 0       25           Private  226802          11th                7
# 1       38           Private   89814       HS-grad                9
# 2       28         Local-gov  336951    Assoc-acdm               12
# 3       44           Private  160323  Some-college               10
# 4       18                 ?  103497  Some-college               10
# ...    ...               ...     ...           ...              ...
# 38457   22           Private  137591  Some-college               10
# 38458   53           Private  274276       HS-grad                9
# 38459   42           Private  341757  Some-college               10
# 38460   36           Private  218542       HS-grad                9
# 38463   39  Self-emp-not-inc   52187       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# ...

# %%
df.education.value_counts()
# Out:
# HS-grad         12504
# Some-college     8560
# Bachelors        6356
# Masters          2097
# Assoc-voc        1622
# 11th             1438
# Assoc-acdm       1236
# 10th             1095
# 7th-8th           745
# Prof-school       627
# 9th               585
# 12th              496
# Doctorate         457
# 5th-6th           396
# 1st-4th           187
# Preschool          63
# Name: education, dtype: int64

# %%
lowest_hrs=df["hours-per-week"].min()

# %%
lowest_hrs
# Out:
# 1.0

# %%
slackers = df[df["hours-per-week"] == lowest_hrs]

# %%
percentage_wealthy_people=(len(slackers[slackers["income"]==">50K"])/len(slackers))*100

# %%
percentage_wealthy_people
# Out:
# 14.285714285714285

# %%
wealth_percentages = (df[df["income"] == ">50K"]["native-country"].value_counts() / df["native-country"].value_counts())*100
wealth_percentages
# Out:
# ?                             25.937031
# Cambodia                      25.000000
# Canada                        36.000000
# China                         26.262626
# Columbia                       6.250000
# Cuba                          21.621622
# Dominican-Republic             6.250000
# Ecuador                       11.111111
# El-Salvador                    6.250000
# England                       38.679245
# France                        42.307692
# Germany                       27.160494
# Greece                        39.024390
# Guatemala                      1.449275
# Haiti                         12.121212
# Holand-Netherlands                  NaN
# Honduras                      13.333333
# Hong                          30.000000
# Hungary                       28.571429
# India                         41.284404
# Iran                          34.000000
# Ireland                       34.375000
# Italy                         38.461538
# ...

# %%
highest_earning_country = wealth_percentages.idxmax()
highest_earning_country
# Out:
# 'Taiwan'

# %%
highest_earning_country_percentage = round(wealth_percentages.max(), 1)
highest_earning_country_percentage
# Out:
# 43.1

# %%
rich_indians = df[df["native-country"] == "India"]
rich_indians = rich_indians[rich_indians["income"] == ">50K"]
top_IN_occupation = rich_indians['occupation'].value_counts().idxmax()

# %%
rich_indians
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 1556    33         State-gov  150688     Doctorate               16
# 1890    45       Federal-gov  110884     Bachelors               13
# 2359    53  Self-emp-not-inc   93449   Prof-school               15
# 2924    46  Self-emp-not-inc  135339       HS-grad                9
# 3110    41       Federal-gov  350387       Masters               14
# 3401    63           Private   76286       Masters               14
# 4701    41      Self-emp-inc   56019   Prof-school               15
# 4842    52  Self-emp-not-inc   98642       HS-grad                9
# 4854    39         Local-gov  123983     Bachelors               13
# 5971    39           Private   79586  Some-college               10
# 6229    47         State-gov   29023     Doctorate               16
# 6602    30           Private  164802     Bachelors               13
# 8035    31           Private  124483       Masters               14
# ...

# %%
top_IN_occupation
# Out:
# 'Prof-specialty'
